# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
pip install apyori
# Out:
# Requirement already satisfied: apyori in /usr/local/lib/python3.7/dist-packages (1.1.2)

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
from apyori import apriori
import time

# %% [markdown]
# # Load the Dataset

# %%
store_data = pd.read_csv('/content/gdrive/MyDrive/Apriori-and-FP-growth-CSE477/chess.csv', header = None)

# %%
store_data
# Out:
#       0   1   2   3   4   5   6   7   8   ...  28  29  30  31  32  33  34  35  36
# 0      1   3   5   7   9  11  13  15  17  ...  58  60  62  64  66  68  70  72  74
# 1      1   3   5   7   9  12  13  15  17  ...  58  60  62  64  66  68  70  72  74
# 2      1   3   5   7   9  12  13  16  17  ...  58  60  62  64  66  68  70  72  74
# 3      1   3   5   7   9  11  13  15  17  ...  58  60  62  64  66  68  70  72  74
# 4      1   3   5   7   9  11  13  15  17  ...  58  60  62  64  66  68  70  72  74
# ...   ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 3191   2   4   5   7   9  11  13  16  17  ...  58  61  62  64  67  68  70  73  74
# 3192   2   4   5   7   9  11  13  16  17  ...  58  61  62  64  67  68  70  73  74
# 3193   2   4   5   7   9  11  13  16  17  ...  58  61  62  64  67  68  70  73  74
# 3194   2   4   5   8   9  11  13  16  17  ...  58  61  62  64  67  68  71  73  74
# 3195   2   4   5   8   9  11  13  16  17  ...  58  61  62  64  67  68  71  73  74
#
# [3196 rows x 37 columns]

# %%
store_data.fillna(0,inplace=True)

# %%
store_data.head()
store_data=store_data.astype(int)
store_data
# Out:
#       0   1   2   3   4   5   6   7   8   ...  28  29  30  31  32  33  34  35  36
# 0      1   3   5   7   9  11  13  15  17  ...  58  60  62  64  66  68  70  72  74
# 1      1   3   5   7   9  12  13  15  17  ...  58  60  62  64  66  68  70  72  74
# 2      1   3   5   7   9  12  13  16  17  ...  58  60  62  64  66  68  70  72  74
# 3      1   3   5   7   9  11  13  15  17  ...  58  60  62  64  66  68  70  72  74
# 4      1   3   5   7   9  11  13  15  17  ...  58  60  62  64  66  68  70  72  74
# ...   ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 3191   2   4   5   7   9  11  13  16  17  ...  58  61  62  64  67  68  70  73  74
# 3192   2   4   5   7   9  11  13  16  17  ...  58  61  62  64  67  68  70  73  74
# 3193   2   4   5   7   9  11  13  16  17  ...  58  61  62  64  67  68  70  73  74
# 3194   2   4   5   8   9  11  13  16  17  ...  58  61  62  64  67  68  71  73  74
# 3195   2   4   5   8   9  11  13  16  17  ...  58  61  62  64  67  68  71  73  74
#
# [3196 rows x 37 columns]

# %%
rowlength = len(store_data)
no_features = len(store_data.values[0])

# %% [markdown]
# ### Remove all 0 value which converted from nan

# %%
records = []
for i in range(0, rowlength):
    records.append([int(store_data.values[i,j]) for j in range(0, no_features)if int(store_data.values[i,j]) != 0])

# %%
threshold = 1
total_time = []
threshold_val = []

for i in range(0,8):
  start = time.time()
  rules = apriori(records,min_support=threshold)
  output = list(rules)
  end = time.time()
  total_time.append(end-start)
  threshold_val.append(threshold)
  threshold = threshold - 0.1
  #print(output)

# %%
from matplotlib import pyplot as plt

plt.plot(total_time, threshold_val, label='kosarak dataset')
plt.xlabel("Time (s)")
plt.ylabel("Threshold")
